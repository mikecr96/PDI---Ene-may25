# %%
# %pip install opencv-python

# %%
import cv2 as cv

# %%
'/Users/miguelcamargorojas/Documents/UP/PDI - Ago-dic23/images'
# Out:
# '/Users/miguelcamargorojas/Documents/UP/PDI - Ago-dic23/images'

# %%
r"C:\users\miguel\images\mariposa.jpg"
# Out:
# 'C:\\users\\miguel\\images\\mariposa.jpg'

# %%
"\i"
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# /var/folders/vr/9n_h2gsj7m16qv6j55xbdp2m0000gn/T/ipykernel_27169/1979973647.py:1: SyntaxWarning: invalid escape sequence '\i'
#   "\i"
# '\\i'

# %%
print("\\")
# Out:
# \

# %%
img = cv.imread('/Users/miguelcamargorojas/Documents/UP/PDI - Ago-dic23/images/butterfly.jpg')

# %%
img2 = cv.imread("/Users/PDI/perrito.jpg")
# Out:
# [ WARN:0@0.094] global loadsave.cpp:268 findDecoder imread_('/Users/PDI/perrito.jpg'): can't open/read file: check file path/integrity

# %%
type(img)
# Out:
# numpy.ndarray

# %%
type(img2)
# Out:
# NoneType

# %%
img + 2
# Out:
# array([[[ 49,  90,  52],
#         [ 49,  90,  52],
#         [ 50,  89,  51],
#         ...,
#         [172, 152, 147],
#         [174, 153, 156],
#         [176, 152, 164]],
#
#        [[ 52,  93,  55],
#         [ 50,  91,  53],
#         [ 48,  87,  49],
#         ...,
#         [173, 152, 151],
#         [175, 153, 158],
#         [176, 153, 167]],
#
#        [[ 55,  96,  58],
#         [ 50,  91,  53],
#         [ 45,  84,  46],
#         ...,
#         [170, 151, 154],
#         [173, 154, 163],
#         [174, 155, 170]],
#
#        ...,
#
#        [[ 45, 125,  60],
#         [ 46, 124,  60],
#         [ 48, 123,  61],
#         ...,
#         [105, 225, 220],
#         [ 96, 216, 205],
#         [ 90, 207, 192]],
#
#        [[ 43, 123,  58],
#         [ 44, 122,  58],
#         [ 47, 122,  60],
#         ...,
#         [105, 225, 220],
#         [ 97, 219, 208],
#         [ 94, 211, 196]],
#
#        [[ 47, 127,  62],
#         [ 48, 126,  62],
#         [ 51, 126,  64],
# ...

# %%
# img2 + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 img2 + 2
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
# ESTO NO SE HACE

# cv.imshow("VENTANA", img)

# %%
# %pip install matplotlib

# %%
# from matplotlib import pyplot as plt
import matplotlib.pyplot as plt

# %%
plt.imshow(img)
plt.show()
