# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv.imread('/Users/miguelcamargorojas/Documents/UP/PDI - Ene-may25/images/aloeL.jpg', 0)
plt.imshow(img, "gray")
plt.show()

# %%
img_bin = cv.threshold(img, 127, 255, cv.THRESH_BINARY)[1]
plt.imshow(img_bin, 'gray')
plt.show()

# %%
s_e = np.ones((3,3) , np.uint8)

# %%
s_e
# Out:
# array([[1, 1, 1],
#        [1, 1, 1],
#        [1, 1, 1]], dtype=uint8)

# %%
img_bin_erode = cv.erode(img_bin, s_e, iterations=2)
plt.imshow(img_bin_erode, 'gray')
plt.show()

# %% [markdown]
# ---
# 02-may-25

# %%
img = cv.imread("/Users/miguelcamargorojas/Documents/UP/PDI - Ene-may25/images/j.png", 0)

# %%
img_bin = cv.threshold(img, 127, 1, cv.THRESH_BINARY)[1]
plt.imshow(img_bin, "gray")
plt.show()

# %%
s_e = np.ones((3,3), dtype=np.uint8)

# %%
img_bin_erode = cv.erode(img_bin, s_e, iterations=3)
plt.imshow(img_bin_erode, "gray")
plt.show()

# %% [markdown]
# ---

# %%
img_bin = cv.threshold(img, 127, 1, cv.THRESH_BINARY_INV)[1]
plt.imshow(img_bin, "gray")
plt.show()

# %%
img_bin_erode = cv.erode(img_bin, s_e, iterations=3)
plt.imshow(img_bin_erode, "gray")
plt.show()

# %% [markdown]
# ---
# Dilate

# %%
img = cv.imread("/Users/miguelcamargorojas/Documents/UP/PDI - Ene-may25/images/j.png", 0)
img_bin = cv.threshold(img, 127, 1, cv.THRESH_BINARY)[1]
plt.imshow(img_bin, "gray")
plt.show()

# %%
img_bin_dil = cv.dilate(img_bin, s_e, iterations=4)
plt.imshow(img_bin_dil, "gray")
plt.show()
